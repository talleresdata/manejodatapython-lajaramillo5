# %%
import pandas as pd
import sys
import datetime as dt
import numpy as np
import matplotlib.pyplot as plt
import matplotlib


# %matplotlib inline

# %%
df = pd.read_json('data/log-course2.json')

# %%
print (df.shape)
# Out:
# (51261, 14)

# %%
df.keys()
# Out:
# Index(['accept_language', 'agent', 'context', 'event', 'event_source',
#        'event_type', 'host', 'ip', 'name', 'page', 'referer', 'session',
#        'time', 'username'],
#       dtype='object')

# %%
print (df.agent.unique())
# Out:
# ['Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/71.0.3578.98 Safari/537.36 OPR/58.0.3135.127'
#  'Mozilla/5.0 (Windows NT 10.0; Win64; x64; rv:66.0) Gecko/20100101 Firefox/66.0'
#  'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/73.0.3683.86 Safari/537.36'
#  'Mozilla/5.0 (Linux; Android 7.0; SM-G935V) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/72.0.3626.121 Mobile Safari/537.36'
#  'Mozilla/5.0 (Windows NT 6.3; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/73.0.3683.86 Safari/537.36'
#  'Mozilla/5.0 (compatible; SemrushBot/3~bl; +http://www.semrush.com/bot.html)'
#  'Mozilla/5.0 (Linux; Android 8.1.0; Redmi 6) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/70.0.3538.110 Mobile Safari/537.36'
#  'Mozilla/5.0 (Linux; Android 8.0.0; SM-G570M) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/73.0.3683.90 Mobile Safari/537.36'
# ...

# %%
df.agent.value_counts()[:20].sort_values(inplace=False).plot('barh');
# https://stackoverflow.com/questions/44123874/dataframe-object-has-no-attribute-sort

# %%
df[df['username'].str.strip()=='JocelyneCastillo'].agent.value_counts()[:15].sort_values(inplace=False).plot('barh');

# %%
print (df.time.unique())
# Out:
# ['2019-04-01T04:28:26.189835+00:00' '2019-04-01T04:28:27.321273+00:00'
#  '2019-04-01T04:36:10.029097+00:00' ... '2019-05-14T22:11:47.721495+00:00'
#  '2019-05-14T22:14:45.074775+00:00' '2019-05-14T22:14:45.659784+00:00']

# %%
df[df['ip'].str.strip()=='190.152.205.187'].time.value_counts()[:15].sort_values(inplace=False).plot(kind='pie', title=u'Gráfico');

# %%
usuario1 = df[df['username'].str.strip()=='danieltapia00'].groupby('ip').username.count()
usuario2 = df[df['username'].str.strip()=='JocelyneCastillo'].groupby('ip').username.count()
usuario1.plot(label='danieltapia00')
usuario2.plot(label='JocelyneCastillo')
plt.legend(loc='best')
# Out:
# c:\users\laju\appdata\local\programs\python\python37-32\lib\site-packages\pandas\plotting\_core.py:1001: UserWarning: Attempting to set identical left==right results
# in singular transformations; automatically expanding.
# left=0.0, right=0.0
#   ax.set_xlim(left, right)

# %%
df[df['event_type'].str.strip()=='/i18n.js'].username.value_counts()[:15].sort_values(inplace=False).plot(kind='bar', title=u'Gráfico');

# %%
usuario4 = df[df['event_type'].str.strip()=='/register'].groupby('agent').username.count()
usuario5 = df[df['event_type'].str.strip()=='/dashboard'].groupby('agent').username.count()
usuario4.plot(label='/register')
usuario5.plot(label='/dashboard')
plt.legend(loc='right')

# %%
df.event_type.value_counts()[:10].sort_values(inplace=False).plot('bar');
